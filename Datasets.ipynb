# %%
# display output from all cmds just like Python shell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %matplotlib inline

import sklearn
from sklearn import datasets as d
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

print 'sklearn version = {}'.format(sklearn.__version__)
# Out:
# sklearn version = 0.18

# %%
# ----------

d.get_data_home()
d.clear_data_home()
# Out:
# '/Users/vissan1/scikit_learn_data'

# %%
# ----------
# load datasets
# ----------

boston = d.load_boston()
dir(boston)

boston.feature_names
X, y = boston.data, boston.target

type(X)
X.shape

type(y)
y.shape

X[0:5,]
# Out:
# ['DESCR', 'data', 'feature_names', 'target']
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'],
#       dtype='|S7')
# numpy.ndarray
# (506, 13)
# numpy.ndarray
# (506,)
# array([[  6.32000000e-03,   1.80000000e+01,   2.31000000e+00,
#           0.00000000e+00,   5.38000000e-01,   6.57500000e+00,
#           6.52000000e+01,   4.09000000e+00,   1.00000000e+00,
#           2.96000000e+02,   1.53000000e+01,   3.96900000e+02,
#           4.98000000e+00],
#        [  2.73100000e-02,   0.00000000e+00,   7.07000000e+00,
#           0.00000000e+00,   4.69000000e-01,   6.42100000e+00,
#           7.89000000e+01,   4.96710000e+00,   2.00000000e+00,
#           2.42000000e+02,   1.78000000e+01,   3.96900000e+02,
#           9.14000000e+00],
#        [  2.72900000e-02,   0.00000000e+00,   7.07000000e+00,
#           0.00000000e+00,   4.69000000e-01,   7.18500000e+00,
#           6.11000000e+01,   4.96710000e+00,   2.00000000e+00,
#           2.42000000e+02,   1.78000000e+01,   3.92830000e+02,
#           4.03000000e+00],
#        [  3.23700000e-02,   0.00000000e+00,   2.18000000e+00,
#           0.00000000e+00,   4.58000000e-01,   6.99800000e+00,
#           4.58000000e+01,   6.06220000e+00,   3.00000000e+00,
#           2.22000000e+02,   1.87000000e+01,   3.94630000e+02,
#           2.94000000e+00],
#        [  6.90500000e-02,   0.00000000e+00,   2.18000000e+00,
#           0.00000000e+00,   4.58000000e-01,   7.14700000e+00,
#           5.42000000e+01,   6.06220000e+00,   3.00000000e+00,
#           2.22000000e+02,   1.87000000e+01,   3.96900000e+02,
#           5.33000000e+00]])

# %%
# ----------
# fetch data sets
# ----------

covtype = d.fetch_covtype()
dir(covtype)
X, y = covtype.data, covtype.target

X.shape
y.shape

print covtype.DESCR
# Out:
# ['DESCR', 'data', 'target']
# (581012, 54)
# (581012,)
# Forest covertype dataset.
#
# A classic dataset for classification benchmarks, featuring categorical and
# real-valued features.
#
# The dataset page is available from UCI Machine Learning Repository
#
#     http://archive.ics.uci.edu/ml/datasets/Covertype
#
# Courtesy of Jock A. Blackard and Colorado State University.

# %%
# ----------
# Explore make_blobs
# ----------

from sklearn.datasets import make_blobs

X, y = make_blobs(n_samples=25, n_features=2, centers=3, random_state=1)
df = pd.DataFrame(X)
df = df.round(2)
df.columns = ['Feature 1', 'Feature 2']
df.shape

df2 = pd.DataFrame(y)
df2.columns = ['Class']

df = pd.concat([df, df2], axis=1)

sns.lmplot('Feature 1', 'Feature 2', data=df, palette='Set1', hue='Class', 
           markers=['o', 'x', '^'], scatter_kws={'s':30}, fit_reg=False)
plt.title('3 blobs with random centers, stdev=1.0')
# Out:
# (25, 2)

# %%
centers = np.array([[-15,2],[0,2],[15,2]])
X, y = make_blobs(n_samples=24, centers=centers, cluster_std=[0.25,0.5,1], center_box=[-20,20], random_state=1)

df = pd.DataFrame(X)
df = df.round(2)
df.columns = ['Feature 1', 'Feature 2']
df.shape

df2 = pd.DataFrame(y)
df2.columns = ['Class']

df = pd.concat([df, df2],axis=1)

sns.lmplot('Feature 1', 'Feature 2', data=df, hue='Class', palette='Set1', markers=['o', 'x', '^'], scatter_kws={'s':30}, fit_reg=False)
plt.title('3 blobs with fixed centers and fixed stdevs')
# Out:
# (24, 2)

# %%
# ----------
# Explore make_classification
# ----------

from sklearn.datasets import make_classification

X, y = make_classification(n_samples=24, n_features=2, n_informative=2, n_redundant=0, n_repeated=0, 
                           n_classes=3, n_clusters_per_class=1, random_state=1)
df = pd.DataFrame(np.round(X,2))
df.columns = ['Feature 1', 'Feature 2']
type(df)
df.shape

df2 = pd.DataFrame(y)
df2.columns = ['Class']

df = pd.concat([df, df2], axis=1)

g = sns.PairGrid(df, palette='Set1', hue='Class')
g = g.map(plt.scatter)
plt.subplots_adjust(top=0.9)
g.fig.suptitle('Classification: 24 samples, 3 classes, 2 informative features, 1 cluster/class')
# Out:
# pandas.core.frame.DataFrame
# (24, 2)

# %%
X, y = make_classification(n_samples=24, n_features=5, n_informative=3, n_redundant=1, n_repeated=1, 
                           n_classes=3, n_clusters_per_class=2, random_state=1)
df = pd.DataFrame(np.round(X,2))
df.columns = ['Feature 1', 'Feature 2', 'Feature 3', 'Feature 4', 'Feature 5']
type(df)
df.shape

df2 = pd.DataFrame(y)
df2.columns = ['Class']

df = pd.concat([df, df2], axis=1)
df


g = sns.PairGrid(df, palette='Set1', hue='Class', vars=['Feature 1', 'Feature 2', 'Feature 3', 'Feature 4', 'Feature 5'])
g = g.map(plt.scatter)
plt.subplots_adjust(top=0.9)
g.fig.suptitle('Classification: 24 samples, 3/5 informative features, 3 classes, 2 clusters/class')
# Out:
# pandas.core.frame.DataFrame
# (24, 5)
#     Feature 1  Feature 2  Feature 3  Feature 4  Feature 5  Class
# 0       -0.86      -0.40      -1.68       0.14      -0.40      1
# 1       -0.91      -1.07       0.83      -1.49      -1.07      1
# 2        0.86       2.96       1.24       0.47       2.96      0
# 3       -1.48       0.14       0.99      -1.95       0.14      1
# 4       -1.87      -0.05      -1.78      -0.70      -0.05      2
# 5       -0.75       1.44      -2.93       1.24       1.44      0
# 6       -0.41      -2.67      -1.40       0.09      -2.67      0
# 7        0.44       0.54      -0.53       0.79       0.54      2
# 8        0.08      -1.03       0.35      -0.28      -1.03      1
# 9       -1.26       0.63      -2.25       0.25       0.63      2
# 10       1.79       0.54       0.75       1.31       0.54      0
# 11       0.19      -0.61      -0.21       0.22      -0.61      1
# 12       1.52       1.04      -1.82       2.65       1.04      2
# 13       0.35       1.27       1.44      -0.35       1.27      0
# 14      -1.13      -0.66      -0.96      -0.57      -0.66      0
# 15      -0.65      -1.13      -1.81       0.31      -1.13      0
# 16       0.08      -0.57      -1.02       0.60      -0.57      1
# 17       1.32      -0.57      -2.06       2.38      -0.57      1
# 18      -0.64      -0.14      -2.09       0.62      -0.14      2
# 19       2.25      -0.95       0.19       1.86      -0.95      0
# 20      -1.20       0.03      -2.49       0.36       0.03      2
# 21      -0.54       2.68       0.41      -0.39       2.68      2
# 22      -1.54       0.88       0.50      -1.61       0.88      1
# 23       0.35       2.48       0.88       0.14       2.48      2

# %%
# ----------
# Explore make_circles
# ----------

from sklearn.datasets import make_circles

X, y = make_circles(n_samples=25, random_state=1)
df = pd.DataFrame(X)
df = df.round(2)
df.columns = ['Feature 1', 'Feature 2']

df2 = pd.DataFrame(y)
df2.shape
df2.columns = ['Class']

df = pd.concat([df, df2], axis=1)
df

g = sns.lmplot(x='Feature 1', y='Feature 2', data=df, hue='Class', 
               palette='Set1', scatter_kws={'s':50}, fit_reg=False)
plt.subplots_adjust(top=0.9)
g.fig.suptitle('Circles: 24 samples, scale=0.8, no noise')
# Out:
# (24, 1)
#     Feature 1  Feature 2  Class
# 0        0.69       0.40      1
# 1       -0.80       0.00      1
# 2        0.00       1.00      0
# 3        0.40       0.69      1
# 4       -0.40      -0.69      1
# 5       -0.69       0.40      1
# 6        0.50      -0.87      0
# 7       -0.50       0.87      0
# 8        0.50       0.87      0
# 9       -0.69      -0.40      1
# 10      -1.00       0.00      0
# 11      -0.87      -0.50      0
# 12      -0.00      -0.80      1
# 13       0.87       0.50      0
# 14      -0.40       0.69      1
# 15       1.00       0.00      0
# 16       0.00       0.80      1
# 17       0.69      -0.40      1
# 18       0.40      -0.69      1
# 19      -0.00      -1.00      0
# 20      -0.50      -0.87      0
# 21       0.80       0.00      1
# 22       0.87      -0.50      0
# 23      -0.87       0.50      0

# %%
X, y = make_circles(n_samples=25, noise=0.25, random_state=1)
df = pd.DataFrame(X)
df = df.round(2)
df.columns = ['Feature 1', 'Feature 2']

df2 = pd.DataFrame(y)
df2.columns = ['Class']
df = pd.concat([df, df2], axis=1)

df

g = sns.lmplot(x='Feature 1', y='Feature 2', data=df, hue='Class', 
               palette='Set1', scatter_kws={'s': 30}, fit_reg=False)
plt.subplots_adjust(top=0.9)
g.fig.suptitle('Circles: 24 samples, scale=0.8, noise=0.25')
# Out:
#     Feature 1  Feature 2  Class
# 0        0.74       0.01      1
# 1       -0.82       0.21      1
# 2        0.17       0.97      0
# 3        0.58       0.93      1
# 4       -0.12      -0.68      1
# 5       -0.60       0.49      1
# 6        0.46      -0.89      0
# 7       -0.27       1.29      0
# 8        0.28       1.30      0
# 9       -0.85      -0.63      1
# 10      -0.91      -0.12      0
# 11      -0.98      -0.52      0
# 12       0.38      -0.51      1
# 13       0.75       0.05      0
# 14      -0.63       0.68      1
# 15       0.79       0.01      0
# 16       0.18       0.38      1
# 17       1.19      -0.11      1
# 18       0.45      -1.08      1
# 19      -0.00      -0.84      0
# 20      -0.11      -0.81      0
# 21       0.83       0.25      1
# 22       1.11      -0.53      0
# 23      -0.69      -0.06      0

# %%
# ----------
# Explore make_gaussian_quantiles
# ----------

from sklearn.datasets import make_gaussian_quantiles

X, y = make_gaussian_quantiles(n_samples=25, random_state=1)
df = pd.DataFrame(X)
df.columns = ['Feature 1', 'Feature 2']
df = df.round(2)


df2 = pd.DataFrame(y)
df2.columns = ['Class']
df = pd.concat([df, df2], axis=1)
df

g = sns.lmplot(x='Feature 1', y='Feature 2', data=df, hue='Class',
              palette='Set1', scatter_kws={'s':30}, fit_reg=False)
plt.subplots_adjust(top=0.9)
g.fig.suptitle('Gaussian quantiles: 25 samples')
# Out:
#     Feature 1  Feature 2  Class
# 0       -0.67      -0.01      0
# 1       -1.12       0.23      1
# 2       -0.27       0.53      0
# 3        0.05      -0.64      0
# 4        1.66       0.74      2
# 5       -0.12      -0.94      1
# 6        0.19       2.10      2
# 7       -0.53      -1.07      1
# 8       -0.32      -0.38      0
# 9        1.13      -1.10      2
# 10      -0.75       1.69      2
# 11       0.04       0.58      0
# 12       0.32      -0.25      0
# 13      -0.19      -0.89      1
# 14       1.62      -0.61      2
# 15       0.87      -2.30      2
# 16      -1.10       1.14      2
# 17       1.46      -2.06      2
# 18       0.12       0.62      0
# 19       1.74      -0.76      2
# 20      -0.69      -0.85      1
# 21       0.90       0.50      1
# 22      -0.17      -0.88      1
# 23       0.90      -0.68      1
# 24      -0.69      -0.40      0

# %%
X, y = make_gaussian_quantiles(n_samples=25, n_features=3, mean=[1,2,3], n_classes=3, random_state=1)

df = pd.DataFrame(X)
df = df.round(2)
df.columns = ['Feature 1', 'Feature 2', 'Feature 3']

df2 = pd.DataFrame(y)
df2.columns = ['Class']
df = pd.concat([df, df2], axis=1)
df

g = sns.PairGrid(df, hue='Class', palette='Set1')
g = g.map(plt.scatter)
plt.subplots_adjust(top=0.9)
g = g.fig.suptitle('Gaussian Quantiles: 25 samples, 3 features, 2 classes, fixed means, unit covariance')
# Out:
#     Feature 1  Feature 2  Feature 3  Class
# 0       -0.07       2.87       0.70      2
# 1        2.13       3.52       5.19      2
# 2       -0.12       2.23       4.66      2
# 3        1.16       2.88       3.32      0
# 4        1.93       2.29       3.89      1
# 5        0.75       3.46       0.94      2
# 6        2.62       1.39       2.47      2
# 7        2.14       2.90       3.50      1
# 8        1.74       1.81       2.11      1
# 9        0.06       1.73       3.53      0
# 10       1.04       2.58       1.90      1
# 11       0.31       1.60       2.31      0
# 12      -0.40       0.56       2.50      2
# 13       0.25       3.25       3.51      1
# 14       0.79       2.59       3.84      0
# 15       0.68       1.62       4.13      1
# 16       0.36       2.19       5.10      2
# 17       1.90       1.32       2.88      0
# 18       0.70       2.49       2.92      0
# 19       0.65       0.86       2.65      1
# 20       1.12       2.62       3.30      0
# 21       2.74       1.24       3.32      2
# 22       0.25       3.69       3.05      2
# 23      -0.10       1.83       2.12      1
# 24       0.15       1.33       2.99      0

# %%
# ----------
# Explore make_moons
# ----------

from sklearn.datasets import make_moons

X, y = make_moons(n_samples=25, random_state=1)
df = pd.DataFrame(X)
df = df.round(2)
df.columns = ['Feature 1', 'Feature 2']

df2 = pd.DataFrame(y)
df2.columns = ['Class']
df = pd.concat([df,df2], axis=1)
df

g = sns.lmplot(x='Feature 1', y='Feature 2', data=df, hue='Class',
              palette='Set1', scatter_kws={'s':30}, fit_reg=False)
plt.subplots_adjust(top=0.9)
g.fig.suptitle('Moons: 25 samples, no noise')
# Out:
#     Feature 1  Feature 2  Class
# 0        0.13       0.00      1
# 1        0.03       0.24      1
# 2        0.74      -0.47      1
# 3        0.65       0.76      0
# 4        1.71      -0.21      1
# 5       -0.96       0.28      0
# 6        1.00      -0.50      1
# 7        1.26      -0.47      1
# 8        0.42       0.91      0
# 9        0.84       0.54      0
# 10       1.50      -0.37      1
# 11      -0.14       0.99      0
# 12      -0.42       0.91      0
# 13       1.87      -0.00      1
# 14       0.96       0.28      0
# 15       0.50      -0.37      1
# 16       1.00       0.00      0
# 17       0.29      -0.21      1
# 18       2.00       0.50      1
# 19       1.97       0.24      1
# 20      -0.84       0.54      0
# 21      -0.65       0.76      0
# 22       0.00       0.50      0
# 23      -1.00       0.00      0
# 24       0.14       0.99      0

# %%
X, y = make_moons(n_samples=25, noise=0.25, random_state=1)

df = pd.DataFrame(X)
df = df.round(2)
df.columns = ['Feature 1', 'Feature 2']

df2 = pd.DataFrame(y)
df2.columns = ['Class']
df = pd.concat([df, df2], axis=1)
df

g = sns.lmplot(x='Feature 1', y='Feature 2', data=df, hue='Class',
              palette='Set1', scatter_kws={'s':30}, fit_reg=False)
plt.subplots_adjust(top=0.9)
g.fig.suptitle('Moons: 25 samples, noise=0.25')
# Out:
#     Feature 1  Feature 2  Class
# 0        0.18      -0.39      1
# 1        0.01       0.45      1
# 2        0.91      -0.49      1
# 3        0.84       0.99      0
# 4        1.99      -0.19      1
# 5       -0.87       0.38      0
# 6        0.96      -0.52      1
# 7        1.49      -0.04      1
# 8        0.19       1.34      0
# 9        0.68       0.31      0
# 10       1.59      -0.48      1
# 11      -0.26       0.97      0
# 12      -0.04       1.20      0
# 13       1.75      -0.45      1
# 14       0.73       0.26      0
# 15       0.29      -0.35      1
# 16       1.18      -0.42      0
# 17       0.79       0.08      1
# 18       2.05       0.11      1
# 19       1.96       0.40      1
# 20      -0.45       0.60      0
# 21      -0.63       1.01      0
# 22       0.24       0.47      0
# 23      -0.83      -0.56      0
# 24      -0.17       1.34      0

# %%
# ----------
# Explore make_regression
# ----------

from sklearn.datasets import make_regression

X, y, coef = make_regression(n_samples=25, n_features=2, n_informative=2, coef=True, random_state=1)

df = pd.DataFrame(X)
df = df.round(2)
df.columns = ['Feature 1', 'Feature 2']

df2 = pd.DataFrame(y)
df2.columns = ['Response']
df2 = df2.round(2)

df = pd.concat([df, df2], axis=1)
df

coef

g = sns.PairGrid(df, palette='Set1', x_vars=['Feature 1', 'Feature 2'], y_vars=['Response'])
g = g.map(plt.scatter)
plt.subplots_adjust(top=0.8)
g.fig.suptitle('Regression: 25 samples, 2 informative features, no bias, no noise')

g = sns.lmplot(x='Feature 1', y='Feature 2', data=df, fit_reg=False)
plt.subplots_adjust(top=0.9)
g.fig.suptitle('Feature 1 vs. Feature 2')
# Out:
#     Feature 1  Feature 2  Response
# 0        0.58       0.04     11.83
# 1       -0.76       1.74    147.16
# 2       -0.40      -0.69    -67.94
# 3       -2.06       1.46    103.77
# 4        0.23      -1.12    -97.72
# 5       -0.38      -0.32    -34.41
# 6       -0.01      -0.67    -60.81
# 7        0.53      -0.27    -16.91
# 8       -0.88      -0.17    -27.65
# 9        2.10       0.19     46.12
# 10      -1.07      -0.53    -62.47
# 11       0.74       1.66    160.15
# 12       1.14      -1.10    -83.69
# 13      -0.61       1.62    138.33
# 14      -2.30       0.87     46.54
# 15       0.62       0.12     19.34
# 16      -0.85      -0.69    -73.70
# 17       1.69      -0.75    -44.23
# 18      -0.94      -0.12    -23.97
# 19      -0.64       0.05     -4.17
# 20      -1.10       1.13     87.30
# 21      -0.25       0.32     25.39
# 22      -0.89      -0.19    -29.53
# 23       0.50       0.90     88.36
# 24      -0.68       0.90     71.98
# array([ 13.74747041,  90.34019153])

# %%
X, y = make_regression(n_samples=25, n_features=3, n_informative=2, random_state=1)

df = pd.concat([pd.DataFrame(X), pd.DataFrame(y)], axis=1)
df = df.round(2)
df.columns = ['Feature 1', 'Feature 2', 'Feature 3', 'Response']

g = sns.pairplot(df, kind='reg')

for i, j in zip(*np.triu_indices_from(g.axes, 1)):
    g.axes[i,j].set_visible(False)

plt.subplots_adjust(top=0.9)
g.fig.suptitle('Regression: 25 samples, 2/3 informative features, no bias, no noise')
