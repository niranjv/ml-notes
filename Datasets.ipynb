# %%
# display output from all cmds just like Python shell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %matplotlib inline

import sklearn
from sklearn import datasets as d
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

print 'sklearn version = {}'.format(sklearn.__version__)

# ----------
# Out:
# sklearn version = 0.18

# %%
d.get_data_home()
d.clear_data_home()

# ----------
# Out:
# '/Users/vissan1/scikit_learn_data'

# %%
boston = d.load_boston()
dir(boston)

boston.feature_names
X, y = boston.data, boston.target

type(X)
X.shape

type(y)
y.shape

X[0:5,]

# ----------
# Out:
# ['DESCR', 'data', 'feature_names', 'target']
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'],
#       dtype='|S7')
# numpy.ndarray
# (506, 13)
# numpy.ndarray
# (506,)
# array([[  6.32000000e-03,   1.80000000e+01,   2.31000000e+00,
#           0.00000000e+00,   5.38000000e-01,   6.57500000e+00,
#           6.52000000e+01,   4.09000000e+00,   1.00000000e+00,
#           2.96000000e+02,   1.53000000e+01,   3.96900000e+02,
#           4.98000000e+00],
#        [  2.73100000e-02,   0.00000000e+00,   7.07000000e+00,
#           0.00000000e+00,   4.69000000e-01,   6.42100000e+00,
#           7.89000000e+01,   4.96710000e+00,   2.00000000e+00,
#           2.42000000e+02,   1.78000000e+01,   3.96900000e+02,
#           9.14000000e+00],
#        [  2.72900000e-02,   0.00000000e+00,   7.07000000e+00,
#           0.00000000e+00,   4.69000000e-01,   7.18500000e+00,
#           6.11000000e+01,   4.96710000e+00,   2.00000000e+00,
#           2.42000000e+02,   1.78000000e+01,   3.92830000e+02,
#           4.03000000e+00],
#        [  3.23700000e-02,   0.00000000e+00,   2.18000000e+00,
#           0.00000000e+00,   4.58000000e-01,   6.99800000e+00,
#           4.58000000e+01,   6.06220000e+00,   3.00000000e+00,
#           2.22000000e+02,   1.87000000e+01,   3.94630000e+02,
#           2.94000000e+00],
#        [  6.90500000e-02,   0.00000000e+00,   2.18000000e+00,
#           0.00000000e+00,   4.58000000e-01,   7.14700000e+00,
#           5.42000000e+01,   6.06220000e+00,   3.00000000e+00,
#           2.22000000e+02,   1.87000000e+01,   3.96900000e+02,
#           5.33000000e+00]])

# %%
from sklearn.datasets import make_blobs
# ----------
# Explore make_blobs
# ----------

X, blob_index = make_blobs(n_samples=25, n_features=2, centers=3)
X = np.round(X, 2)

sns.regplot(X[:,0], X[:,1], fit_reg=False, color='red')
plt.title('3 blobs with random centers')
plt.xlabel('Axis 1')
plt.ylabel('Axis 2')

# %%
centers = np.array([[-15,2],[0,2],[15,2]])
X, blob_index = make_blobs(n_samples=24, centers=centers, cluster_std=[0.25,0.5,1], center_box=[-20,20])
X = np.round(X, 2)

X.shape
blob_index.shape

sns.regplot(X[:,0], X[:,1], fit_reg=False, color='red')
plt.title('3 blobs with fixed centers and fixed stdevs')
plt.xlabel('Axis 1')
plt.ylabel('Axis 2')
# Out:
# (24, 2)
# (24,)

# %%
from sklearn.datasets import make_classification
# ----------
# Explore make_classification
# ----------

X, y = make_classification(n_samples=24, n_features=5, n_informative=2, n_redundant=2, n_repeated=1)
df = pd.DataFrame(np.round(X,2))
type(df)
df.shape
df

type(y)
y.shape
y

g = sns.PairGrid(df)
g = g.map(plt.scatter)
# Out:
# pandas.core.frame.DataFrame
# (24, 5)
#        0     1     2     3     4
# 0  -1.25 -1.25  2.62 -0.93 -2.95
# 1   0.88  0.88 -0.46 -0.47  0.83
# 2  -0.86 -0.86  0.69  0.26 -1.02
# 3   0.41  0.41  0.53 -0.83 -0.30
# 4   0.68  0.68 -1.03  0.19  1.25
# 5  -0.36 -0.36  0.76 -0.27 -0.86
# 6  -1.16 -1.16 -2.20  2.89  1.47
# 7   0.11  0.11  0.19 -0.26 -0.12
# 8  -0.05 -0.05  1.17 -0.90 -1.09
# 9   0.05  0.05  1.65 -1.39 -1.48
# 10 -1.53 -1.53 -0.18  1.60 -0.54
# 11  1.60  1.60 -0.14 -1.42  0.86
# 12 -1.62 -1.62  1.23  0.55 -1.86
# 13  1.33  1.33 -0.19 -1.12  0.78
# 14 -1.89 -1.89 -2.04  3.46  0.99
# 15 -1.10 -1.10  1.50 -0.17 -1.87
# 16 -1.40 -1.40 -1.12  2.24  0.38
# 17 -0.47 -0.47  2.35 -1.46 -2.35
# 18  1.69  1.69 -0.91 -0.87  1.60
# 19  1.39  1.39 -1.53 -0.09  2.03
# 20  0.37  0.37  1.27 -1.38 -0.98
# 21 -0.29 -0.29  1.81 -1.19 -1.78
# 22  0.34  0.34 -0.15 -0.21  0.29
# 23 -0.11 -0.11  2.28 -1.74 -2.13
# numpy.ndarray
# (24,)
# array([1, 1, 1, 0, 1, 0, 0, 1, 0, 1, 0, 1, 0, 1, 0, 0, 0, 1, 1, 1, 0, 1, 0,
#        1])
